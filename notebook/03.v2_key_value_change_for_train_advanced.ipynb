# %%
import json

# %%
def write_to_file(data, file_path):
        with open(file_path, "w", encoding="utf-8") as file:
            json.dump(data, file, ensure_ascii=False, indent=4, separators=(',', ':'))


def transform_and_save(data_path, save_path):

    with open(data_path, 'r') as file:
        data = json.load(file)

    for d in data:
        instruction = d["instruction"]
        input_text = d["input"]
        output_text = d["output"]

        d["text"] = (
            "Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request."
            "### Instruction: {}"
            "### Input: {}"
            "### Response: {}"
            "\""
        ).format(instruction, input_text, output_text)
        
    with open(save_path, "w", encoding="utf-8") as file:
            json.dump(data, file, ensure_ascii=False, indent=4, separators=(',', ':'))

# %%
def write_to_file(data, file_path):
        with open(file_path, "w", encoding="utf-8") as file:
            json.dump(data, file, ensure_ascii=False, indent=4, separators=(',', ':'))

# %%
def write_to_file(data, file_path):
        with open(file_path, "w", encoding="utf-8") as file:
            json.dump(data, file, ensure_ascii=False, indent=4, separators=(',', ':'))

# %%
write_to_file(data, r"C:\Users\parkm\Desktop\llm\ko-alpaca-lingo\data\dbdu\ShareGPT-74k-ko\ko_shargpt_deepl_translate_cleaned_v2.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\parkm\Desktop\llm\ko-alpaca-lingo\notebook\03.v2_key_value_change_for_train_advanced.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/parkm/Desktop/llm/ko-alpaca-lingo/notebook/03.v2_key_value_change_for_train_advanced.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> write_to_file(data, r"C:\Users\parkm\Desktop\llm\ko-alpaca-lingo\data\dbdu\ShareGPT-74k-ko\ko_shargpt_deepl_translate_cleaned_v2.json")
#
# NameError: name 'data' is not defined

# %%
# !pip install autotrain-advanced
# Out:
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Using cached bitsandbytes-0.39.1-py3-none-any.whl (97.1 MB)
# ...
#   Using cached PyJWT-2.6.0-py3-none-any.whl (20 kB)
# ...
#   Using cached accelerate-0.20.3-py3-none-any.whl (227 kB)
# ...
#   Using cached pandas-1.5.3-cp38-cp38-win_amd64.whl (11.0 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.2
#     Uninstalling pandas-1.4.2:
#       Successfully uninstalled pandas-1.4.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.20.0
#     Uninstalling streamlit-1.20.0:
#       Successfully uninstalled streamlit-1.20.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.15.1
#     Uninstalling huggingface-hub-0.15.1:
#       Successfully uninstalled huggingface-hub-0.15.1
# ...
